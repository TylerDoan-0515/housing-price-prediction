# %% [raw]
# Dream-To-Delay

# %%
import pandas as pd
homevalue2011 = pd.read_csv("data/Value and Purchase Price/2011 Value and Purchase.csv")
homevalue2013 = pd.read_csv("data/Value and Purchase Price/2013 Value and Purchase.csv")
homevalue2015 = pd.read_csv("data/Value and Purchase Price/2015 Value and Purchase.csv")
homevalue2017 = pd.read_csv("data/Value and Purchase Price/2017 Value and Purchase.csv")
homevalue2019 = pd.read_csv("data/Value and Purchase Price/2019 Value and Purchase.csv")
homevalue2021 = pd.read_csv("data/Value and Purchase Price/2021 Value and Purchase.csv")
homevalue2023 = pd.read_csv("data/Value and Purchase Price/2023 Value and Purchase.csv")

print(homevalue2011)
print(homevalue2013)
print(homevalue2015)
print(homevalue2017)
print(homevalue2019)
print(homevalue2021)
print(homevalue2023)
# Out:
#            Characteristics Estimate
# 0                    Total   76,053
# 1                      NaN      NaN
# 2                    Value      NaN
# 3                      NaN      NaN
# 4        Less than $10,000    1,536
# ..                     ...      ...
# 126                    NaN      NaN
# 127  First home ever owned   31,828
# 128         Not first home   42,917
# 129           Not reported    1,307
# 130                    NaN      NaN
#
# [131 rows x 2 columns]
#            Characteristics Estimate
# 0                    Total   75,650
# 1                      NaN      NaN
# 2                    Value      NaN
# 3                      NaN      NaN
# 4        Less than $10,000    1,672
# ..                     ...      ...
# 126                    NaN      NaN
# 127  First home ever owned   31,588
# 128         Not first home   42,520
# 129           Not reported    1,542
# 130                    NaN      NaN
#
# [131 rows x 2 columns]
# ...
